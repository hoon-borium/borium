# %%
from datetime import date, timedelta

today = date.today()
yesterday = today - timedelta(days=1)
last_week_start = yesterday - datetime.timedelta(days=7)
last_week_start = yesterday - datetime.timedelta(days=7)

print(yesterday)
# Out:
# 2025-11-05

# %%
yesterday = datetime.date(2025, 11, 3)
last_week_start = yesterday - datetime.timedelta(days=7)
last_week_end = yesterday - datetime.timedelta(days=1)

# 날짜 필터링
df['날짜'] = pd.to_datetime(df['날짜'])
last_week = df[(df['날짜'] >= last_week_start) & (df['날짜'] <= last_week_end)]
yesterday_data = df[df['날짜'] == yesterday]

# 계산
last_week_avg = last_week['매출'].mean()
yesterday_sales = yesterday_data['매출'].sum()

diff = yesterday_sales - last_week_avg
print(f"어제 매출은 {yesterday_sales:,.0f}원으로 지난주 평균보다 {diff:,.0f}원 차이.")
# Out:
#   Cell In[4], line 1
#     ollama pull llama3
#            ^
# SyntaxError: invalid syntax
